# %% [markdown]
# # Installer les dépendances et les configurations

# %%
# !pip install -U spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m spacy download fr_core_news_sm
# Out:
# 2023-06-15 08:59:56.752291: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-15 08:59:57.988634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 47.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import spacy
from spacy import displacy
from spacy.matcher import Matcher
import re

# %% [markdown]
# # Chargement du modéle

# %%
nlp = spacy.load("fr_core_news_sm")

# %% [markdown]
# # REGEX

# %%
iban_patterns=[
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^FR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})([0-9]{2})\s?"}}
    ]},

    {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:FR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP": "{5}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
    ]},


{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^AL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([a-zA-Z0-9]{4}\s?){4}\s?"}}
    ]},


  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:AL)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
   ]},

#AD[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([a-zA-Z0-9]{4}\s?){3}\s?

{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^AD[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([a-zA-Z0-9]{4}\s?){3}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:AD)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}","OP":"{3}"}},
    ]},

#AT[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^AT[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:AT)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
    ]},
#AZ[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^AZ[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){5}\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:AZ)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
    ]},
#BH[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^BH[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{2})\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:BH)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
    ]},
#BY[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^BY[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){5}\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:BY)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
    ]},
#BE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^BE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:BE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        ]},
#BA[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^BA[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:BA)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        ]},
#BR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{3})([a-zA-Z]{1}\s?)([a-zA-Z0-9]{1})\s?
#BR15 0000 0000 0000 1093 2840 814 P2
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^BR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{3})([a-zA-Z]{1}\s?)([a-zA-Z0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:BR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        ]},
#BG[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){1}([0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){1}([a-zA-Z0-9]{2})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^BG[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){1}([0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){1}([a-zA-Z0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:BG)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        ]},
#CR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^CR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:CR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#HR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{1})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^HR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:HR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        ]},

#CY[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([a-zA-Z0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^CY[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([a-zA-Z0-9]{4}\s?){4}\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:CY)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{4}"},
        ]},
#CZ[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^CZ[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:CZ)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},

        ]},
#DK[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^DK[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:DK)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#DO[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^DO[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:DO)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        ]},
 #TL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{3})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^TL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:TL)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#EE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?
   {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^EE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:EE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        ]},
#FO[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^FO[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:FO)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#FI[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^FI[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:FI)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#GE[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{2})([0-9]{2}\s?)([0-9]{4}\s?){3}([0-9]{2})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^GE[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{2})([0-9]{2}\s?)([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:GE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#DE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^DE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:DE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#GI[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{3})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^GI[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:GI)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        ]},
#GR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{3})\s?
#GR96 0810 0010 0000 0123 4567 890
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^GR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]){3}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:GR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#GL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^GL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:GL)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#GT[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^GT[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:GT)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{5}"},
        ]},
#HU[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){6}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^HU[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){6}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:HU)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{6}"},
        ]},
#IS[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{2})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^IS[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:IS)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#IE[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){3}([0-9]{2})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^IE[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:IE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},

#IL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{3})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^IL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:IL)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#IT[a-zA-Z0-9]{2}\s?([a-zA-Z]{1})([0-9]{3}\s?)([0-9]{4}\s?){1}([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{3})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^IT[a-zA-Z0-9]{2}\s?([a-zA-Z]{1})([0-9]{3}\s?)([0-9]{4}\s?){1}([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:IT)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{1}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        ]},
#JO[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){5}([0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^JO[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){5}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:JO)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#KZ[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^KZ[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:KZ)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        ]},

#XK[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{4}\s?){2}([0-9]{2})([0-9]{2}\s?)\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^XK[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{4}\s?){2}([0-9]{2})([0-9]{2}\s?)\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:XK)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"},"OP":"{2}"},
        ]},
#KW[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}([a-zA-Z0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^KW[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}([a-zA-Z0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:KW)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        ]},
#LV[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{1})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^LV[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:LV)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        ]},
#LB[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^LB[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:LB)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{5}"},
        ]},
#LI[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^LI[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:LI)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        ]},
#LT[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^LT[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:LT)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        ]},
#LU[a-zA-Z0-9]{2}\s?([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){3}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^LU[a-zA-Z0-9]{2}\s?([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){3}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:LU)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{3}"},
        ]},
#MK[a-zA-Z0-9]{2}\s?([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})([0-9]{2})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^MK[a-zA-Z0-9]{2}\s?([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:MK)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#MT[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{3})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^MT[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{3})\s?"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:MT)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        ]},
#MR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{3})\s?
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^MR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:MR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#MU[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){4}([0-9]{3})([a-zA-Z]{1}\s?)([a-zA-Z]{2})\s?
#MU43 BOMM 0101 1234 5678 9101 000 MUR
 {"label":"IBAN","pattern":[
       {"TEXT":{"REGEX":"^MU[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){4}([0-9]{3}\s?)([a-zA-Z]{3}\s?)"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:MU)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{3}"}},
        ]},
#MC[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})([0-9]{2})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^MC[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:MC)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#MD[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^MD[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:MD)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{4}"},
        ]},
#ME[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^ME[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:ME)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#NL[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){2}([0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^NL[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){2}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:NL)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#NO[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([0-9]{3})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^NO[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){2}([0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:NO)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#PK[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^PK[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:PK)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        ]},
#PS[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){5}([0-9]{1})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^PS[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){5}([0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:PS)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        ]},
#PL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){6}\s?
#PL10 1050 0099 7603 1234 5678 9123
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^PL[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){6}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:PL)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{6}"},
        ]},
#PT[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}([0-9]{1})\s?
#PT50 0033 0000 5013 1901 229 05
{"label":"IBAN","pattern":[
       {"TEXT":{"REGEX":"^PT[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{3}\s?){1}([0-9]{2}\s?){1}"}}
    ]},

 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:PT)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#QA[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}([a-zA-Z0-9]{1})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^QA[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){5}([a-zA-Z0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:QA)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{5}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        ]},
#RO[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^RO[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([a-zA-Z0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:RO)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{4}"},
        ]},
#SM[a-zA-Z0-9]{2}\s?([a-zA-Z]{1})([0-9]{3}\s?)([0-9]{4}\s?){1}([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{3})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^SM[a-zA-Z0-9]{2}\s?([a-zA-Z]{1})([0-9]{3}\s?)([0-9]{4}\s?){1}([0-9]{3})([a-zA-Z0-9]{1}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:SM)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{1}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{2}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        ]},
#SA[a-zA-Z0-9]{2}\s?([0-9]{2})([a-zA-Z0-9]{2}\s?)([a-zA-Z0-9]{4}\s?){4}\s?
#SA44 2000 0001 2345 6789 1234
 {"label":"IBAN","pattern":[
       {"TEXT":{"REGEX":"^SA[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:SA)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        ]},
#RS[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?
  {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^RS[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:RS)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#SK[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^SK[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:SK)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        ]},
#SI[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{3})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^SI[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){3}([0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:SI)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#ES[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^ES[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:ES)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        ]},
#SE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^SE[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:SE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        ]},
#CH[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){2}([a-zA-Z0-9]{1})\s?
#CH56 0483 5012 3456 7800 9
{"label":"IBAN","pattern":[
       {"TEXT":{"REGEX":"^CH[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){4}\s?([0-9]{1})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:CH)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        ]},
#TN[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^TN[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){5}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:TN)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{5}"},
        ]},
#TR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^TR[a-zA-Z0-9]{2}\s?([0-9]{4}\s?){1}([0-9]{1})([a-zA-Z0-9]{3}\s?)([a-zA-Z0-9]{4}\s?){3}([a-zA-Z0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:TR)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{3}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{2}"}},
        ]},
#AE[a-zA-Z0-9]{2}\s?([0-9]{3})([0-9]{1}\s?)([0-9]{4}\s?){3}([0-9]{3})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^AE[a-zA-Z0-9]{2}\s?([0-9]{3})([0-9]{1}\s?)([0-9]{4}\s?){3}([0-9]{3})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:AE)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        ]},
#GB[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){3}([0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^GB[a-zA-Z0-9]{2}\s?([a-zA-Z]{4}\s?){1}([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:GB)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#VA[a-zA-Z0-9]{2}\s?([0-9]{3})([0-9]{1}\s?)([0-9]{4}\s?){3}([0-9]{2})\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^VA[a-zA-Z0-9]{2}\s?([0-9]{3})([0-9]{1}\s?)([0-9]{4}\s?){3}([0-9]{2})\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:VA)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[0-9]{3}"}},
        {"TEXT":{"REGEX":"[0-9]{1}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{3}"},
        {"TEXT":{"REGEX":"[0-9]{2}"}},
        ]},
#VG[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){4}\s?
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^VG[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){4}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:VG)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{4}"},
        ]},

#LC14 BOSL 1234 5678 9012 3456 7890 1234
{"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"^LC[a-zA-Z0-9]{2}\s?([a-zA-Z0-9]{4}\s?){1}([0-9]{4}\s?){6}\s?"}}
    ]},
 {"label":"IBAN","pattern":[
        {"TEXT":{"REGEX":"(?:LC)[0-9]{2}"}},
        {"TEXT":{"REGEX":"[a-zA-Z0-9]{4}"}},
        {"TEXT":{"REGEX":"[0-9]{4}"},"OP":"{6}"},
        ]}
]

# %%
ruler = nlp.add_pipe("entity_ruler",before="ner")
ruler.add_patterns(iban_patterns)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/entityruler.py:342: UserWarning: [W035] Discarding subpattern '{'REGEX': '[a-zA-Z0-9]{4}', 'OP': '{3}'}' due to an unrecognized attribute or operator.
#   self.matcher.add(label, [pattern])

# %% [markdown]
# # TEST

# %%
iban1="""
Banque
10096
Guichet
18070
84000
N° compte
00036367501
Clé
25
Devise
EUR
Identifiant international de compte bancaire
IBAN (International Bank Account Number)
FR76 1009 6180 7000 0363 6750 125
Domiciliation
CIC AIX JEANNE D'ARC
BIC (Bank Identifier Code)
CMCIFRPP
"""

# %%
doc=nlp(iban1)
print(doc)
displacy.render(doc,style="ent",minify=True,jupyter=True)
# Out:
# Banque
# 10096
# Guichet
# 18070
# 84000
# N° compte
# 00036367501
# Clé
# 25
# Devise
# EUR
# Identifiant international de compte bancaire
# IBAN (International Bank Account Number)
# FR76 1009 6180 7000 0363 6750 125
# Domiciliation
# CIC AIX JEANNE D'ARC
# BIC (Bank Identifier Code)
# CMCIFRPP
# ...
